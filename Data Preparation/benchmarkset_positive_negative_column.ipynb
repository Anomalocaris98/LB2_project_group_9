# %%
import pandas as pd
import numpy as np


dataset = pd.read_csv("/home/anomalocaris/LB2_project_group_9/Data Preparation/benchmark_arricchito.tsv", sep="\t")

# Crea la colonna target 0/1
dataset['positive/negative'] = np.where(dataset['SP cleavage'] == 'False', 0, 1)

dataset.to_csv("/home/anomalocaris/LB2_project_group_9/Data Preparation/benchmark_arricchito.tsv",
               sep="\t",
               index=False)

"""
# Estrai le sequenze in una lista
seqs = dataset["Sequence"].tolist()
labels = dataset["positive/negative"].tolist()

# Salva le liste
all_seqs.append(seqs)
all_labels.append(labels
"""
# Out:
# '\n# Estrai le sequenze in una lista\nseqs = dataset["Sequence"].tolist()\nlabels = dataset["positive/negative"].tolist()\n\n# Salva le liste\nall_seqs.append(seqs)\nall_labels.append(labels\n'
